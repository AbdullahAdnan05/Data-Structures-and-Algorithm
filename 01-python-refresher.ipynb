# %%
a = [1, 2, 3, 4, 5]
b = [6, 7, 8, 9, 10]

merged = list(zip(a, b))

# %%
merged
# Out:
# [(1, 6), (2, 7), (3, 8), (4, 9), (5, 10)]

# %%
# Real world usecase of ZIP: combining column headers with row values
# much more along with usecases, here : http://stackoverflow.com/questions/2429692
feilds = ["id", "name", "location"]
values = ["13", "bill", "redmond"]
dict(zip(feilds, values))
# Out:
# {'id': '13', 'name': 'bill', 'location': 'redmond'}
